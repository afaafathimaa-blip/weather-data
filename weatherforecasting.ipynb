# %% [markdown]
# # WEATHER FORECASTING

# %% [markdown]
# ## My First Project

# %%
import pandas as pd # data handling
import matplotlib.pyplot as plt # visualization
import seaborn as sns # visualization

# %% [markdown]
# - pandas is used for data manipulation

# %% [markdown]
# ### Loading Datasets

# %%
df = pd.read_csv("weather.csv")
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.tail()
# Out:
#           country location_name  latitude  longitude         timezone  \
# 136628  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 136629    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 136631     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 136628          1776666600  2026-04-20 02:30                 17.5
# 136629          1776666600  2026-04-20 13:30                 28.3
# 136630          1776666600  2026-04-20 09:30                 21.0
# 136631          1776666600  2026-04-20 08:30                 21.5
# 136632          1776666600  2026-04-20 08:30                 20.0
#
#         temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 136628                    63.6  Partly Cloudy  ...               7.85
# ...

# %%
df.sample(6)
# Out:
#                     country  location_name  latitude  longitude  \
# 125907              Belgium       Brussels   50.8333     4.3333
# 51446               Vietnam          Hanoi   21.0333   105.8500
# 44268               Vanuatu      Port Vila  -17.7333   168.3167
# 1478             Mozambique         Maputo  -25.9700    32.5900
# 115550  Trinidad and Tobago  Port Of Spain   10.6500   -61.5167
# 129987               Turkey         Ankara   39.9272    32.8644
#
#                      timezone  last_updated_epoch      last_updated  \
# 125907        Europe/Brussels          1771915500  2026-02-24 07:45
# 51446            Asia/Bangkok          1738751400  2025-02-05 17:30
# 44268           Pacific/Efate          1735554600  2024-12-30 21:30
# 1478            Africa/Maputo          1716387300  2024-05-22 16:15
# 115550  America/Port_of_Spain          1767164400  2025-12-31 03:00
# 129987        Europe/Istanbul          1773729900  2026-03-17 09:45
#
# ...

# %%
df.dtypes # shows column heading on left and data types on right
# Out:
# country                             str
# location_name                       str
# latitude                        float64
# longitude                       float64
# timezone                            str
# last_updated_epoch                int64
# last_updated                        str
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                      str
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                      str
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %%
df.columns # display column names
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='str')

# %%
df.shape # display no. of rows and columns
# Out:
# (136633, 41)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 136633 entries, 0 to 136632
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       136633 non-null  str
#  1   location_name                 136633 non-null  str
#  2   latitude                      136633 non-null  float64
#  3   longitude                     136633 non-null  float64
#  4   timezone                      136633 non-null  str
#  5   last_updated_epoch            136633 non-null  int64
#  6   last_updated                  136633 non-null  str
#  7   temperature_celsius           136633 non-null  float64
#  8   temperature_fahrenheit        136633 non-null  float64
#  9   condition_text                136633 non-null  str
#  10  wind_mph                      136633 non-null  float64
#  11  wind_kph                      136633 non-null  float64
# ...

# %% [markdown]
# - There are total 136633 entries
# - There are 41 columns
# - Data types used : 21 float64, 9 int64 and 11 str
# - 42.7 MB memory is used
# - There are no null columns
# - Some column's data type have mistakes (time should have int data type)

# %%
df.latitude
# Out:
# 0         34.5200
# 1         41.3300
# 2         36.7600
# 3         42.5000
# 4         -8.8400
#            ...
# 136628    10.5000
# 136629    21.0333
# 136630    15.3547
# 136631   -15.4167
# 136632   -17.8178
# Name: latitude, Length: 136633, dtype: float64

# %%
df[['sunrise','moonset']]
# Out:
#        sunrise moonset
# 0        04:50   01:11
# 1        05:21   02:14
# 2        05:40   02:14
# 3        06:31   03:31
# 4        06:12   00:38
# ...        ...     ...
# 136628   06:14   22:12
# 136629   05:34   21:34
# 136630   05:46   21:39
# 136631   06:15   20:35
# 136632   06:06   20:18
#
# [136633 rows x 2 columns]

# %% [markdown]
# ### Filtering

# %%
df[df['latitude']<30]
# Out:
#                     country location_name  latitude  longitude  \
# 4                    Angola        Luanda   -8.8400    13.2300
# 5       Antigua and Barbuda  Saint John's   17.1200   -61.8500
# 6                 Argentina  Buenos Aires  -34.5900   -58.6700
# 8                 Australia      Canberra  -35.2800   149.2200
# 11                  Bahamas        Nassau   25.0800   -77.3500
# ...                     ...           ...       ...        ...
# 136628            Venezuela       Caracas   10.5000   -66.9167
# 136629              Vietnam         Hanoi   21.0333   105.8500
# 136630                Yemen         Sanaa   15.3547    44.2067
# 136631               Zambia        Lusaka  -15.4167    28.2833
# 136632             Zimbabwe        Harare  -17.8178    31.0447
#
#                               timezone  last_updated_epoch      last_updated  \
# 4                        Africa/Luanda          1715849100  2024-05-16 09:45
# ...

# %%
df[df['longitude']>30]
# Out:
#             country location_name  latitude  longitude          timezone  \
# 0       Afghanistan         Kabul   34.5200    69.1800        Asia/Kabul
# 7           Armenia       Yerevan   40.1800    44.5100      Asia/Yerevan
# 8         Australia      Canberra  -35.2800   149.2200  Australia/Sydney
# 10       Azerbaijan          Baku   40.4000    49.8800         Asia/Baku
# 12          Bahrain        Manama   26.2400    50.5800      Asia/Bahrain
# ...             ...           ...       ...        ...               ...
# 136626   Uzbekistan      Tashkent   41.3167    69.2500     Asia/Tashkent
# 136627      Vanuatu     Port Vila  -17.7333   168.3167     Pacific/Efate
# 136629      Vietnam         Hanoi   21.0333   105.8500      Asia/Bangkok
# 136630        Yemen         Sanaa   15.3547    44.2067         Asia/Aden
# 136632     Zimbabwe        Harare  -17.8178    31.0447     Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
df[(df['temperature_celsius']<20)&(df['air_quality_us-epa-index']==1)]
# Out:
#                          country      location_name  latitude  longitude  \
# 1                        Albania             Tirana   41.3300    19.8200
# 3                        Andorra   Andorra La Vella   42.5000     1.5200
# 6                      Argentina       Buenos Aires  -34.5900   -58.6700
# 7                        Armenia            Yerevan   40.1800    44.5100
# 8                      Australia           Canberra  -35.2800   149.2200
# ...                          ...                ...       ...        ...
# 136613                  Bulgaria                Lom   43.8139    23.2361
# 136621                   Ukraine               Kyiv   50.4333    30.5167
# 136623            United Kingdom             London   51.5171    -0.1062
# 136624  United States of America  Washington Harbor   48.0792  -123.0439
# 136628                 Venezuela            Caracas   10.5000   -66.9167
#
#                               timezone  last_updated_epoch      last_updated  \
# ...

# %%
df.temperature_fahrenheit
# Out:
# 0         79.8
# 1         66.2
# 2         73.4
# 3         43.3
# 4         78.8
#           ...
# 136628    63.6
# 136629    82.9
# 136630    69.7
# 136631    70.8
# 136632    68.1
# Name: temperature_fahrenheit, Length: 136633, dtype: float64

# %%
# selecting columns
df['condition_text']
# Out:
# 0         Partly Cloudy
# 1         Partly cloudy
# 2                 Sunny
# 3         Light drizzle
# 4         Partly cloudy
#               ...
# 136628    Partly Cloudy
# 136629           Cloudy
# 136630            Sunny
# 136631            Sunny
# 136632            Sunny
# Name: condition_text, Length: 136633, dtype: str

# %%
# selecting rows i=index and loc = location
df.iloc[19] # single row
# Out:
# country                                                         Bhutan
# location_name                                                  Thimphu
# latitude                                                         27.48
# longitude                                                         89.6
# timezone                                                  Asia/Thimphu
# last_updated_epoch                                          1715849100
# last_updated                                          2024-05-16 14:45
# temperature_celsius                                               18.2
# temperature_fahrenheit                                            64.8
# condition_text                  Patchy light rain in area with thunder
# wind_mph                                                           7.2
# wind_kph                                                          11.5
# wind_degree                                                        142
# ...

# %%
df.iloc[ 3:64] # portion
# Out:
#                 country     location_name  latitude  longitude  \
# 3               Andorra  Andorra La Vella     42.50       1.52
# 4                Angola            Luanda     -8.84      13.23
# 5   Antigua and Barbuda      Saint John's     17.12     -61.85
# 6             Argentina      Buenos Aires    -34.59     -58.67
# 7               Armenia           Yerevan     40.18      44.51
# ..                  ...               ...       ...        ...
# 59              Finland          Helsinki     60.18      24.93
# 60               France             Paris     48.87       2.33
# 61                Gabon        Libreville      0.38       9.45
# 62               Gambia            Banjul     13.45     -16.58
# 63              Georgia           Tbilisi     41.73      44.79
#
#                           timezone  last_updated_epoch      last_updated  \
# 3                   Europe/Andorra          1715849100  2024-05-16 10:45
# ...

# %%
# loc method 
df.loc[63,'air_quality_PM2.5']
# Out:
# np.float64(2.0)

# %% [markdown]
# ### Renaming column

# %%
df.rename(columns={"location_name":"place"},inplace=True)
df
# Out:
#             country             place  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df['condition_text'].value_counts()
# Out:
# condition_text
# Partly cloudy                                  39376
# Sunny                                          39229
# Patchy rain nearby                             11376
# Partly Cloudy                                   8669
# Overcast                                        7410
# Clear                                           7200
# Mist                                            5716
# Light rain                                      4287
# Light rain shower                               3133
# Fog                                             1709
# Cloudy                                          1633
# Moderate or heavy rain with thunder             1090
# Moderate rain                                   1042
# Patchy light rain with thunder                   843
# Light drizzle                                    678
# Light snow                                       523
# Patchy light drizzle                             455
# ...

# %%
# parse last_updated as datetime
df["last_updated"] = pd.to_datetime(df["last_updated"],errors="coerce")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 136633 entries, 0 to 136632
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       136633 non-null  str
#  1   place                         136633 non-null  str
#  2   latitude                      136633 non-null  float64
#  3   longitude                     136633 non-null  float64
#  4   timezone                      136633 non-null  str
#  5   last_updated_epoch            136633 non-null  int64
#  6   last_updated                  136633 non-null  datetime64[us]
#  7   temperature_celsius           136633 non-null  float64
#  8   temperature_fahrenheit        136633 non-null  float64
#  9   condition_text                136633 non-null  str
#  10  wind_mph                      136633 non-null  float64
#  11  wind_kph                      136633 non-null  float64
# ...

# %% [markdown]
# ### deleting columns

# %%
df.drop(columns=['last_updated_epoch'],inplace=True)
df
# Out:
#             country             place  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.drop(columns=['temperature_fahrenheit','air_quality_PM2.5'],inplace=True)
df
# Out:
#             country             place  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 136628    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 136629      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 136630        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 136631       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 136632     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.isnull().sum()
# Out:
# country                         0
# place                           0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated                    0
# temperature_celsius             0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# ...

# %%
df['condition_text'].mode()
# Out:
# 0    Partly cloudy
# Name: condition_text, dtype: str

# %%
num_col = df[['latitude','longitude','temperature_celsius','wind_mph','wind_kph','air_quality_Sulphur_dioxide','air_quality_PM10','moon_illumination']]
for i in num_col:
   
   print(i,df[i].median())
# Out:
# latitude 17.25
# longitude 23.2361
# temperature_celsius 23.9
# wind_mph 6.7
# wind_kph 10.8
# air_quality_Sulphur_dioxide 2.405
# air_quality_PM10 19.98
# moon_illumination 49.0
